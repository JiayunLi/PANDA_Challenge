# %%
# %reload_ext autoreload
# %autoreload 2
## sys package
import os, sys
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"  # specify which GPU(s) to be used
sys.path.append("../")
## warning off
import warnings
warnings.filterwarnings("ignore")

## general package
import random
from tqdm import tqdm_notebook as tqdm
import numpy as np
import pandas as pd
from torch.utils.data import *

## customized package
from input.inputPipeline_seg import *
from model.deeplabv3 import *

# %%
# DATA = "../input/prostate-cancer-grade-assessment"
image_dir = "../input/panda-32x256x256-tiles-data/train/"
csv_file = "../input/panda-16x128x128-tiles-data/4_fold_train.csv"

# %%
mean = torch.tensor([0.5, 0.5, 0.5])
std = torch.tensor([0.5, 0.5, 0.5])
## dataset, can fetch data by dataset[idx]
dataset = PandaPatchDatasetSegInfer(csv_file, image_dir, [mean, std], N = 12)

# %% [markdown]
# ### Segmentation models

# %%
models = []
weights = [f'../train/weights/Deeplabv3Res50_12patch_radboud/Deeplabv3Res50_12patch_radboud_{i}_best.pth.tar' for i in range(4)]
for path in weights:
    state_dict = torch.load(path)
    model = Model(arch='deeplabv3_resnet50', n=6).cuda()
    model.load_state_dict(state_dict)
    model.float()
    model.eval()
    model.cuda()
    models.append(model)

del state_dict

# %% [markdown]
# ### Inference

# %%
bs = 1
sz = 256
dataloader = DataLoader(dataset, batch_size=bs,
                            shuffle=False, num_workers=0, collate_fn=dataloader_collte_fn_infer)
names,preds = [],[] ## record image names and predictions
with torch.no_grad():
    for idx, data in enumerate(dataloader):
        img, name = data
        img = img.float().cuda()
        bs,N,C,h,w = img.shape
        img = torch.stack([img,img.flip(-1),img.flip(-2),img.flip(-1,-2),
                  img.transpose(-1,-2),img.transpose(-1,-2).flip(-1),
                  img.transpose(-1,-2).flip(-2),img.transpose(-1,-2).flip(-1,-2)],1)
        img = img.view(-1, N, C, h, w) # (bs * 8, N, C, w, h)
        p = [model(img) for model in models] # [4, bs * 8, 6]
        print(p[0].shape)
        break
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-129-8207b711edd2> in <module>
#      13                   img.transpose(-1,-2).flip(-2),img.transpose(-1,-2).flip(-1,-2)],1)
#      14         img = img.view(-1, N, C, h, w) # (bs * 8, N, C, w, h)
# ---> 15         p = [model(img) for model in models] # [4, bs * 8, 6]
#      16         print(p[0].shape)
#      17         break
#
# <ipython-input-129-8207b711edd2> in <listcomp>(.0)
#      13                   img.transpose(-1,-2).flip(-2),img.transpose(-1,-2).flip(-1,-2)],1)
#      14         img = img.view(-1, N, C, h, w) # (bs * 8, N, C, w, h)
# ---> 15         p = [model(img) for model in models] # [4, bs * 8, 6]
#      16         print(p[0].shape)
#      17         break
#
# ~/anaconda3/envs/panda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/Documents/Project/panda_bak/prediction_models/tile_concat_wy/model/deeplabv3.py in forward(self, x)
#      34         input_shape = (h, w)
#      35         # contract: features is a dict of tensors
# ---> 36         features = self.backbone(x)
#      37         result = OrderedDict()
#      38         x = features["out"]
#
# ~/anaconda3/envs/panda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/panda/lib/python3.6/site-packages/torchvision/models/_utils.py in forward(self, x)
#      61         out = OrderedDict()
#      62         for name, module in self.items():
# ---> 63             x = module(x)
#      64             if name in self.return_layers:
#      65                 out_name = self.return_layers[name]
#
# ~/anaconda3/envs/panda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/panda/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# ~/anaconda3/envs/panda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/panda/lib/python3.6/site-packages/torchvision/models/resnet.py in forward(self, x)
#     106         out = self.relu(out)
#     107
# --> 108         out = self.conv3(out)
#     109         out = self.bn3(out)
#     110
#
# ~/anaconda3/envs/panda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/panda/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     343
#     344     def forward(self, input):
# --> 345         return self.conv2d_forward(input, self.weight)
#     346
#     347 class Conv3d(_ConvNd):
#
# ~/anaconda3/envs/panda/lib/python3.6/site-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     340                             _pair(0), self.dilation, self.groups)
#     341         return F.conv2d(input, weight, self.bias, self.stride,
# --> 342                         self.padding, self.dilation, self.groups)
#     343
#     344     def forward(self, input):
#
# RuntimeError: CUDA out of memory. Tried to allocate 768.00 MiB (GPU 0; 7.93 GiB total capacity; 5.16 GiB already allocated; 596.19 MiB free; 6.37 GiB reserved in total by PyTorch)

# %% [markdown]
# ## Radboud

# %%
df_train = pd.read_csv(os.path.join(DATA, "train.csv"))
df_train = df_train[df_train.data_provider == 'radboud']
for label in range(0,6):
    df_train[f'percent_{label}'] = None
    df_train[f'count_{label}'] = None

for i in tqdm(range(len(df_train))):
    idx = df_train.iloc[i, 0]
    isup = df_train.iloc[i, 2]
    gleason = df_train.iloc[i, 3]
    mask_files = [os.path.join(MASK, f'{idx}_{j}.png') for j in range(12)]
    if os.path.exists(mask_files[0]):
        masks = [np.expand_dims(open_image(fname),0) for fname in mask_files]
        masks = np.concatenate(masks)
        cnt, feat = extract_features(masks)
        for label in range(0,6):
            df_train[f'count_{label}'].iloc[i] = cnt[label-1]
            df_train[f'percent_{label}'].iloc[i] = feat[label-1]
    else:
        continue
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5160.0), HTML(value='')))

# %%
df_train = df_train.replace(to_replace='None', value=np.nan).dropna()
df_train.reset_index(drop=True)
# Out:
#                               image_id data_provider  isup_grade  \
# 0     0018ae58b01bdadc8e347995b69f99aa       radboud           4
# 1     004dd32d9cd167d9cc31c13b704498af       radboud           1
# 2     0068d4c7529e34fd4c9da863ce01a161       radboud           3
# 3     006f6aa35a78965c92fffd1fbd53a058       radboud           3
# 4     007433133235efc27a39f11df6940829       radboud           0
# ...                                ...           ...         ...
# 5055  ffd2841373b39792ab0c84cccd066e31       radboud           0
# 5056  ffdc59cd580a1468eac0e6a32dd1ff2d       radboud           5
# 5057  ffe06afd66a93258f8fabdef6044e181       radboud           0
# 5058  ffe236a25d4cbed59438220799920749       radboud           2
# 5059  ffe9bcababc858e04840669e788065a1       radboud           4
#
#      gleason_score  percent_0 count_0 percent_1 count_1    percent_2 count_2  \
# 0              4+4          0       0  0.612134  442740   0.00271267    1962
# 1              3+3          0       0  0.957644  629782    0.0423562   27855
# 2              4+3          0       0  0.959698  487514    0.0402235   20433
# 3              4+3          0       0  0.708292  284666            0       0
# 4         negative          0       0  0.955717  654403    0.0442835   30322
# ...            ...        ...     ...       ...     ...          ...     ...
# 5055      negative          0       0  0.861589  641361     0.138411  103032
# 5056           4+5  0.0788637   59924  0.863513  656134  0.000686984     522
# 5057      negative          0       0  0.918352  677851    0.0816483   60266
# 5058           3+4          0       0  0.615882  440984    0.0210162   15048
# 5059           4+4          0       0  0.794427  568361    0.0033546    2400
#
#         percent_3 count_3  percent_4 count_4  percent_5 count_5
# 0               0       0   0.385153  278571          0       0
# 1               0       0          0       0          0       0
# 2     7.87422e-05      40          0       0          0       0
# 3       0.0564487   22687    0.23526   94552          0       0
# 4               0       0          0       0          0       0
# ...           ...     ...        ...     ...        ...     ...
# 5055            0       0          0       0          0       0
# 5056            0       0  0.0569368   43263  0.0788637   59924
# 5057            0       0          0       0          0       0
# 5058     0.296363  212202  0.0667384   47786          0       0
# 5059            0       0   0.202218  144674          0       0
#
# [5060 rows x 16 columns]

# %%
skf = StratifiedKFold(4, shuffle=True, random_state=2020)
splits = list(skf.split(df_train, df_train.isup_grade))

#features = [f"percent_{label}" for label in range(1, 6)] 
features = [f"percent_{label}" for label in range(0, 6)] + [f"count_{label}" for label in range(0, 6)]
target = 'isup_grade'

# %%
from sklearn.neighbors import KNeighborsClassifier

scores = []
for fold in range(4):
    train = df_train.iloc[splits[fold][0]]
    valid = df_train.iloc[splits[fold][1]]
    
    model = KNeighborsClassifier(n_neighbors=5)
    
    model.fit(train[features], train[target])
    
    preds = model.predict(valid[features])
    
    score = cohen_kappa_score(preds, valid[target], weights='quadratic')
    scores.append(score)
    print(f"Fold = {fold}, QWK = {score:.4f}")
    
print(f"Mean = {np.mean(scores):.4f}")
# Out:
# Fold = 0, QWK = 0.7717
# Fold = 1, QWK = 0.7589
# Fold = 2, QWK = 0.7770
# Fold = 3, QWK = 0.7502
# Mean = 0.7645

# %%
# rfc
from sklearn.ensemble import RandomForestClassifier

scores = []
for fold in range(4):
    train = df_train.iloc[splits[fold][0]]
    valid = df_train.iloc[splits[fold][1]]
    
    model = RandomForestClassifier(random_state=42)
    
    model.fit(train[features], train[target])
    
    preds = model.predict(valid[features])
    
    score = cohen_kappa_score(preds, valid[target], weights='quadratic')
    scores.append(score)
    print(f"Fold = {fold}, QWK = {score:.4f}")
    
print(f"Mean = {np.mean(scores):.4f}")
# Out:
# Fold = 0, QWK = 0.9372
# Fold = 1, QWK = 0.9265
# Fold = 2, QWK = 0.9339
# Fold = 3, QWK = 0.9139
# Mean = 0.9279

# %%
df_train[features] = df_train[features].apply(pd.to_numeric, errors = 'coerce')

# %%
# lgb
import lightgbm as lgb

def QWK(preds, dtrain):
    labels = dtrain.get_label()
    preds = np.rint(preds)
    score = cohen_kappa_score(preds, labels, weights='quadratic')
    return ("QWK", score, True)

scores = []
for fold in range(4):
    train = df_train.iloc[splits[fold][0]]
    valid = df_train.iloc[splits[fold][1]]
    
    train_dataset = lgb.Dataset(train[features], train[target])
    valid_dataset = lgb.Dataset(valid[features], valid[target])
    
    params = {
                "objective": 'regression',
                "metric": 'rmse',
                "seed": 42,
                "learning_rate": 0.01,
                "boosting": "gbdt",
            }
        
    model = lgb.train(
                params=params,
                num_boost_round=1000,
                early_stopping_rounds=200,
                train_set=train_dataset,
                valid_sets=[train_dataset, valid_dataset],
                verbose_eval=100,
                feval=QWK,
            )
        
    
    preds = model.predict(valid[features], num_iteration=model.best_iteration)
    preds = np.rint(preds)
    
    score = cohen_kappa_score(preds, valid[target], weights='quadratic')
    scores.append(score)
    
    print(f"Fold = {fold}, QWK = {score:.4f}")
    
print(f"Mean = {np.mean(scores):.4f}")
# Out:
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.839282	training's QWK: 0.809975	valid_1's rmse: 0.836875	valid_1's QWK: 0.802039
# [200]	training's rmse: 0.601463	training's QWK: 0.93593	valid_1's rmse: 0.610676	valid_1's QWK: 0.930569
# [300]	training's rmse: 0.549123	training's QWK: 0.946905	valid_1's rmse: 0.57589	valid_1's QWK: 0.938021
# [400]	training's rmse: 0.530139	training's QWK: 0.949147	valid_1's rmse: 0.575231	valid_1's QWK: 0.936839
# Early stopping, best iteration is:
# [278]	training's rmse: 0.556135	training's QWK: 0.94573	valid_1's rmse: 0.578479	valid_1's QWK: 0.93911
# Fold = 0, QWK = 0.9391
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.832482	training's QWK: 0.793946	valid_1's rmse: 0.850386	valid_1's QWK: 0.78581
# [200]	training's rmse: 0.591465	training's QWK: 0.938665	valid_1's rmse: 0.63373	valid_1's QWK: 0.922456
# [300]	training's rmse: 0.538515	training's QWK: 0.947418	valid_1's rmse: 0.601053	valid_1's QWK: 0.931445
# [400]	training's rmse: 0.519476	training's QWK: 0.950173	valid_1's rmse: 0.599715	valid_1's QWK: 0.931858
# [500]	training's rmse: 0.504963	training's QWK: 0.952751	valid_1's rmse: 0.600558	valid_1's QWK: 0.931391
# [600]	training's rmse: 0.494804	training's QWK: 0.954687	valid_1's rmse: 0.601579	valid_1's QWK: 0.931431
# Early stopping, best iteration is:
# [408]	training's rmse: 0.518528	training's QWK: 0.950242	valid_1's rmse: 0.599657	valid_1's QWK: 0.931858
# Fold = 1, QWK = 0.9319
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.833895	training's QWK: 0.795364	valid_1's rmse: 0.858063	valid_1's QWK: 0.779843
# [200]	training's rmse: 0.591432	training's QWK: 0.937551	valid_1's rmse: 0.64729	valid_1's QWK: 0.924231
# [300]	training's rmse: 0.537433	training's QWK: 0.947397	valid_1's rmse: 0.615395	valid_1's QWK: 0.930292
# [400]	training's rmse: 0.518364	training's QWK: 0.950074	valid_1's rmse: 0.61179	valid_1's QWK: 0.931789
# [500]	training's rmse: 0.504646	training's QWK: 0.951857	valid_1's rmse: 0.613445	valid_1's QWK: 0.932103
# [600]	training's rmse: 0.493065	training's QWK: 0.953964	valid_1's rmse: 0.613254	valid_1's QWK: 0.931782
# Early stopping, best iteration is:
# [418]	training's rmse: 0.516035	training's QWK: 0.951043	valid_1's rmse: 0.611755	valid_1's QWK: 0.931678
# Fold = 2, QWK = 0.9317
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 0.824344	training's QWK: 0.792665	valid_1's rmse: 0.874572	valid_1's QWK: 0.765008
# [200]	training's rmse: 0.576992	training's QWK: 0.942238	valid_1's rmse: 0.673018	valid_1's QWK: 0.918399
# [300]	training's rmse: 0.521374	training's QWK: 0.95234	valid_1's rmse: 0.64832	valid_1's QWK: 0.921142
# [400]	training's rmse: 0.500932	training's QWK: 0.955389	valid_1's rmse: 0.649586	valid_1's QWK: 0.922048
# [500]	training's rmse: 0.485759	training's QWK: 0.957635	valid_1's rmse: 0.653159	valid_1's QWK: 0.921959
# Early stopping, best iteration is:
# [311]	training's rmse: 0.518118	training's QWK: 0.952683	valid_1's rmse: 0.647988	valid_1's QWK: 0.921115
# Fold = 3, QWK = 0.9211
# Mean = 0.9309

# %% [markdown]
# ## Karolinska

# %%
df_train = pd.read_csv(os.path.join(DATA, "train.csv"))
df_train = df_train[df_train.data_provider == 'karolinska']
for label in range(0,3):
    df_train[f'percent_{label}'] = None
    df_train[f'count_{label}'] = None

for i in tqdm(range(len(df_train))):
    idx = df_train.iloc[i, 0]
    isup = df_train.iloc[i, 2]
    gleason = df_train.iloc[i, 3]
    mask_files = [os.path.join(MASK, f'{idx}_{j}.png') for j in range(12)]
    if os.path.exists(mask_files[0]):
        masks = [np.expand_dims(open_image(fname),0) for fname in mask_files]
        masks = np.concatenate(masks)
        cnt, feat = extract_features(masks)
        for label in range(0,3):
            df_train[f'count_{label}'].iloc[i] = cnt[label-1]
            df_train[f'percent_{label}'].iloc[i] = feat[label-1]
    else:
        continue
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5456.0), HTML(value='')))

# %%
df_train = df_train.replace(to_replace='None', value=np.nan).dropna()
df_train.reset_index(drop=True)
# Out:
#                               image_id data_provider  isup_grade  \
# 0     0005f7aaab2800f6170c399693a96917    karolinska           0
# 1     000920ad0b612851f8e01bcc880d9b3d    karolinska           0
# 2     001c62abd11fa4b57bf7a6c603a11bb9    karolinska           4
# 3     001d865e65ef5d2579c190a0e0350d8f    karolinska           0
# 4     002a4db09dad406c85505a00fb6f6144    karolinska           0
# ...                                ...           ...         ...
# 5431  ffb182fa5b636005e21eec384bbf406b    karolinska           0
# 5432  ffc005d56a21efbd034425623f596984    karolinska           2
# 5433  ffc0cbbe28a6345a179d6210ef5c579f    karolinska           4
# 5434  ffcd99c47e57ad2934dc6bbf5edf6675    karolinska           0
# 5435  ffcee00fd033d3ece1408035a7fd4ea7    karolinska           1
#
#      gleason_score percent_0 count_0  percent_1 count_1 percent_2 count_2
# 0              0+0         0       0          1  706016         0       0
# 1              0+0         0       0          1  545488         0       0
# 2              4+4         0       0          0       0         1  738528
# 3              0+0         0       0          1  704624         0       0
# 4              0+0         0       0          1  693268         0       0
# ...            ...       ...     ...        ...     ...       ...     ...
# 5431           0+0         0       0          1  771360         0       0
# 5432           3+4         0       0  0.0235566    3264  0.976443  135296
# 5433           4+4         0       0   0.777093  429944  0.222907  123328
# 5434           0+0         0       0          1  620768         0       0
# 5435           3+3         0       0  0.0094775    6760  0.990523  706508
#
# [5436 rows x 10 columns]

# %%
skf = StratifiedKFold(4, shuffle=True, random_state=2020)
splits = list(skf.split(df_train, df_train.isup_grade))

#features = [f"percent_{label}" for label in range(1, 6)] 
features = [f"percent_{label}" for label in range(0, 3)] + [f"count_{label}" for label in range(0, 3)]
target = 'isup_grade'

# %%
from sklearn.neighbors import KNeighborsClassifier

scores = []
for fold in range(4):
    train = df_train.iloc[splits[fold][0]]
    valid = df_train.iloc[splits[fold][1]]
    
    model = KNeighborsClassifier(n_neighbors=5)
    
    model.fit(train[features], train[target])
    
    preds = model.predict(valid[features])
    
    score = cohen_kappa_score(preds, valid[target], weights='quadratic')
    scores.append(score)
    print(f"Fold = {fold}, QWK = {score:.4f}")
    
print(f"Mean = {np.mean(scores):.4f}")
# Out:
# Fold = 0, QWK = 0.5406
# Fold = 1, QWK = 0.5726
# Fold = 2, QWK = 0.5597
# Fold = 3, QWK = 0.5671
# Mean = 0.5600

# %%
# rfc
from sklearn.ensemble import RandomForestClassifier

scores = []
for fold in range(4):
    train = df_train.iloc[splits[fold][0]]
    valid = df_train.iloc[splits[fold][1]]
    
    model = RandomForestClassifier(random_state=42)
    
    model.fit(train[features], train[target])
    
    preds = model.predict(valid[features])
    
    score = cohen_kappa_score(preds, valid[target], weights='quadratic')
    scores.append(score)
    print(f"Fold = {fold}, QWK = {score:.4f}")
    
print(f"Mean = {np.mean(scores):.4f}")
# Out:
# Fold = 0, QWK = 0.5503
# Fold = 1, QWK = 0.5687
# Fold = 2, QWK = 0.5735
# Fold = 3, QWK = 0.5608
# Mean = 0.5633

# %%
# lgb
import lightgbm as lgb
df_train[features] = df_train[features].apply(pd.to_numeric, errors = 'coerce')
def QWK(preds, dtrain):
    labels = dtrain.get_label()
    preds = np.rint(preds)
    score = cohen_kappa_score(preds, labels, weights='quadratic')
    return ("QWK", score, True)

scores = []
for fold in range(4):
    train = df_train.iloc[splits[fold][0]]
    valid = df_train.iloc[splits[fold][1]]
    
    train_dataset = lgb.Dataset(train[features], train[target])
    valid_dataset = lgb.Dataset(valid[features], valid[target])
    
    params = {
                "objective": 'regression',
                "metric": 'rmse',
                "seed": 42,
                "learning_rate": 0.01,
                "boosting": "gbdt",
            }
        
    model = lgb.train(
                params=params,
                num_boost_round=1000,
                early_stopping_rounds=200,
                train_set=train_dataset,
                valid_sets=[train_dataset, valid_dataset],
                verbose_eval=100,
                feval=QWK,
            )
        
    
    preds = model.predict(valid[features], num_iteration=model.best_iteration)
    preds = np.rint(preds)
    
    score = cohen_kappa_score(preds, valid[target], weights='quadratic')
    scores.append(score)
    
    print(f"Fold = {fold}, QWK = {score:.4f}")
    
print(f"Mean = {np.mean(scores):.4f}")
# Out:
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 1.02338	training's QWK: 0.48069	valid_1's rmse: 1.07574	valid_1's QWK: 0.405391
# [200]	training's rmse: 0.934803	training's QWK: 0.727815	valid_1's rmse: 1.02592	valid_1's QWK: 0.66293
# [300]	training's rmse: 0.908863	training's QWK: 0.74317	valid_1's rmse: 1.02514	valid_1's QWK: 0.668036
# [400]	training's rmse: 0.893952	training's QWK: 0.75206	valid_1's rmse: 1.02963	valid_1's QWK: 0.672874
# Early stopping, best iteration is:
# [256]	training's rmse: 0.918438	training's QWK: 0.734015	valid_1's rmse: 1.02399	valid_1's QWK: 0.66339
# Fold = 0, QWK = 0.6634
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 1.03602	training's QWK: 0.486891	valid_1's rmse: 1.0502	valid_1's QWK: 0.461811
# [200]	training's rmse: 0.949962	training's QWK: 0.711479	valid_1's rmse: 0.987478	valid_1's QWK: 0.694018
# [300]	training's rmse: 0.924728	training's QWK: 0.722137	valid_1's rmse: 0.982392	valid_1's QWK: 0.696942
# [400]	training's rmse: 0.909138	training's QWK: 0.734371	valid_1's rmse: 0.986821	valid_1's QWK: 0.701074
# Early stopping, best iteration is:
# [267]	training's rmse: 0.931102	training's QWK: 0.719353	valid_1's rmse: 0.981441	valid_1's QWK: 0.695607
# Fold = 1, QWK = 0.6956
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 1.02723	training's QWK: 0.453968	valid_1's rmse: 1.07122	valid_1's QWK: 0.423291
# [200]	training's rmse: 0.940164	training's QWK: 0.719177	valid_1's rmse: 1.01568	valid_1's QWK: 0.670879
# [300]	training's rmse: 0.914441	training's QWK: 0.731182	valid_1's rmse: 1.01368	valid_1's QWK: 0.674218
# [400]	training's rmse: 0.900459	training's QWK: 0.743676	valid_1's rmse: 1.01758	valid_1's QWK: 0.680231
# Early stopping, best iteration is:
# [264]	training's rmse: 0.921231	training's QWK: 0.727972	valid_1's rmse: 1.01253	valid_1's QWK: 0.675493
# Fold = 2, QWK = 0.6755
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 1.03095	training's QWK: 0.461683	valid_1's rmse: 1.06565	valid_1's QWK: 0.413886
# [200]	training's rmse: 0.943865	training's QWK: 0.707763	valid_1's rmse: 1.00218	valid_1's QWK: 0.667289
# [300]	training's rmse: 0.918393	training's QWK: 0.735501	valid_1's rmse: 0.996062	valid_1's QWK: 0.67576
# [400]	training's rmse: 0.903354	training's QWK: 0.74777	valid_1's rmse: 1.00011	valid_1's QWK: 0.677573
# Early stopping, best iteration is:
# [260]	training's rmse: 0.926011	training's QWK: 0.730683	valid_1's rmse: 0.995795	valid_1's QWK: 0.675795
# Fold = 3, QWK = 0.6758
# Mean = 0.6776
